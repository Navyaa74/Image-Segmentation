# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randrange

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image = cv2.imread("/content/drive/MyDrive/1.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary_image = cv2.threshold(gray,100,255,cv2.THRESH_BINARY)

# %%
contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
segmented_image = image.copy()
cv2.drawContours(segmented_image, contours, -1,(0,0,255),2)
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [166, 174, 181],
#         ...,
#         [115, 104, 106],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[ 26,  45,  42],
#         [ 22,  40,  39],
#         [ 26,  41,  44],
#         ...,
#         [  2,  46,  83],
#         [ 20,  65, 103],
#         [  1,  44,  87]],
#
#        [[ 22,  41,  38],
#         [ 22,  40,  39],
#         [ 28,  43,  46],
#         ...,
#         [  0,  42,  83],
#         [ 22,  70, 112],
#         [ 10,  61, 104]],
#
#        [[ 22,  38,  37],
#         [ 26,  41,  43],
#         [ 29,  44,  47],
#         ...,
#         [  3,  51,  93],
#         [ 39,  89, 135],
#         [ 20,  76, 123]]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(segmented_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=225x223>
